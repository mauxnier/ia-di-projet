# %% [markdown]
# #### Réalisation du challenge 1

# %%
import json
import pickle
from data_parse import parse_xml_to_dataframe

# %%
# Extrait les données et les transforme selon les besoins
# Ici, vous devez extraire et traiter les données comme vous l'avez fait pour l'entraînement
df_test = parse_xml_to_dataframe("benchmark_HTTPWeb_test.xml")
# df_test = parse_xml_to_dataframe("challenge1/benchmark_SSH_test.xml")
# Out:
# Parsing benchmark_HTTPWeb_test.xml XML file...
# Done parsing XML file in dataframe.
#    appName totalSourceBytes totalDestinationBytes totalDestinationPackets  \
# 0  HTTPWeb              379                   498                       5
# 1  HTTPWeb              377                   498                       5
# 2  HTTPWeb              445                   564                       6
# 3  HTTPWeb              130                    66                       1
# 4  HTTPWeb             1145                 29938                      24
#
#   totalSourcePackets                              sourcePayloadAsBase64  \
# 0                  5  R0VUIC9pbWcvcGVyc29uMDIuanBnIEhUVFAvMS4xDQpIb3...
# 1                  5  R0VUIC9pbWcvbGVhZDA3LmdpZiBIVFRQLzEuMQ0KSG9zdD...
# 2                  6  R0VUIC9pbWcvY2gwM19pbWcwMy5qcGcgSFRUUC8xLjENCk...
# 3                  2                                               None
# 4                 15  R0VUIC9jbi9hYm91dC11cy9jb21wYW55LW92ZXJ2aWV3Lz...
#
# ...

# %% [markdown]
# 2. Chargement du modèle Random Forest

# %%
# # Chemin vers le fichier .pkl où le modèle est enregistré
# file_path = "random_forest_classifier_HTTPWeb.pkl"
# # file_path = 'random_forest_classifier_SSH.pkl'

# # Charger le modèle entraîné à partir d'un fichier
# with open(file_path, "rb") as file:
#     rf_model = pickle.load(file)

# %% [markdown]
# 3. Prédiction des étiquettes pour les données extraites

# %%
# predictions = rf_model.predict(
#     data_test
# )  # Remplacer data_test par les données extraites
# probs = rf_model.predict_proba(data_test)  # Probabilités des prédictions

# %% [markdown]
# 4. Création du fichier de résultats

# %%
# res = {
#     "preds": predictions.tolist(),  # Convertit les prédictions en liste pour JSON
#     "probs": probs.tolist(),  # Convertit les probabilités en liste
#     # ... autres informations requises
# }
# with open("result_file.res", "w") as f:
#     json.dump(res, f)
